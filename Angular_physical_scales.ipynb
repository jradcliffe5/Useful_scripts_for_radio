# %%
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
from scipy.odr import Model, Data, ODR
from scipy.stats import linregress
import numpy as np
import matplotlib.cm as cm
from scipy import constants
import pandas as pd
from matplotlib import rc
from matplotlib import rcParams
from astropy.cosmology import Planck15
from astropy import units as u

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
rcParams['mathtext.default'] = 'regular'
matplotlib.rcParams.update({'font.size': 22})
plt.ioff()

fig_size = plt.rcParams["figure.figsize"]
# Prints: [8.0, 6.0]
print "Current size:", fig_size

# Set figure width to 9 and height to 9
fig_size[1] = 9
fig_size[0] = 9
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
## Inputs
redshift_low = 0
redshift_high = 1
npoints = 5000

VLA_res = 1.5  # in arcsec
eMERLIN_res = 0.2
VLBI_res = 0.005

redshift = np.linspace(redshift_low, redshift_high, npoints)

plt.figure(1)
plt.plot(
    redshift,
    Planck15.kpc_proper_per_arcmin(redshift).to(u.kpc / u.arcsec).value *
    VLA_res,
    label=r'VLA-A - $\theta_{res}\sim$ %.1f"' % VLA_res)
plt.plot(
    redshift,
    Planck15.kpc_proper_per_arcmin(redshift).to(u.kpc / u.arcsec).value *
    eMERLIN_res,
    label=r'eMERLIN - $\theta_{res}\sim$ %.1f"' % eMERLIN_res)
plt.plot(
    redshift,
    Planck15.kpc_proper_per_arcmin(redshift).to(u.kpc / u.arcsec).value *
    VLBI_res,
    label=r'VLBI - $\theta_{res}\sim$ %.3f"' % VLBI_res)
#plt.yscale('log')
plt.ylabel('Physical scale / kpc')
plt.xlabel(r'$z$')
plt.legend()
plt.show()

# %%
Planck15.kpc_proper_per_arcmin(0.03232).to(u.kpc / u.arcsec).value *VLA_res
# Out:
# 1.0000291305366336
